# %%
import pandas as pd
import os
from train_model.incremental_combined_xgboost import PreProcessing, XGBoost
import torch

# %%
torch.cuda.is_available()
# Out:
# False

# %%
os.getcwd()
# Out:
# 'C:\\Users\\saran\\Desktop\\Lufthansa\\Lufthansa-Arrival-Time-Prediction\\playground\\h3'

# %%
os.chdir('..')
os.chdir('..')

# %%
#For incremental
months = ['january', 'february', 'march', 'april', 'may', 'june', 'july', 'august', 'september', 'october', 'november', 'december']

# %%
combined_data = pd.read_csv('combined_data.csv', low_memory=False)

# %%
combined_data = combined_data.iloc[::10, :]
combined_data
# Out:
#          Unnamed: 0  alert  altitude callsign                        day  \
# 0                 0   True   35075.0   DLH445  2022-01-01 00:00:00+00:00
# 10              400  False   35000.0   DLH441  2022-01-01 00:00:00+00:00
# 20              800  False   35000.0   DLH439  2022-01-01 00:00:00+00:00
# 30             1200  False   33025.0   DLH507  2022-01-01 00:00:00+00:00
# 40             1600  False   35000.0   DLH431  2022-01-01 00:00:00+00:00
# ...             ...    ...       ...      ...                        ...
# 3157120     9379160  False   35000.0   DLH445  2023-01-01 00:00:00+00:00
# 3157130     9379560  False   38000.0   DLH631  2023-01-01 00:00:00+00:00
# 3157140     9379960  False   35025.0   DLH445  2023-01-01 00:00:00+00:00
# 3157150     9380360  False   32975.0   DLH511  2023-01-01 00:00:00+00:00
# 3157160     9380760  False   37000.0   DLH441  2023-01-01 00:00:00+00:00
#
#         destination                  firstseen  geoaltitude  groundspeed  \
# ...

# %%
xgb_instance = XGBoost()

# %%
xgb_instance.incremental_xgb(months, 'january')

# %%
xgb_instance.combined_xgb(combined_data,'january')
# Out:
# Doing geo_to_h3
# Doing h3_to_geo_boundary
# dt.hour completed
# Grouping according to hour and h3index completed
# Training on combined data...
# [18:57:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:1517: Empty dataset at worker: 0
# [18:57:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:1517: Empty dataset at worker: 0
# [18:57:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:1517: Empty dataset at worker: 0
# [18:57:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\learner.cc:1517: Empty dataset at worker: 0
# ...
